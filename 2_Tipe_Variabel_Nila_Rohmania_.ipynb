# %% [markdown]
# <a href="https://colab.research.google.com/github/nilarohmania/KKA-X-Semester-1-NilaR/blob/main/2_Tipe_Variabel_Nila_Rohmania_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Konsep Dasar Variabel

# %%
print("nilarohmania.2025@gmail.com")
print("nilarohmania.2025@gmail.com")
print("nilarohmania.2025@gmail.com")
# Out:
# nilarohmania.2025@gmail.com
# nilarohmania.2025@gmail.com
# nilarohmania.2025@gmail.com

# %%
email_user_1 = "nilarohmania.2025@gmail.com"

print(email_user_1)
# Out:
# nilarohmania.2025@gmail.com

# %% [markdown]
# #Peraturan Penulisan Variabel

# %%
#Sensitif terhadap kapital
email_user_2 = "Keenan Akbar"

print(Email_user_2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3762691350.py in <cell line: 0>()
#       2 email_user_2 = "Keenan Akbar"
#       3
# ----> 4 print(Email_user_2)
#
# NameError: name 'Email_user_2' is not defined

# %%
email_user_2 = "Keenan Akbar"

print(email_user_2)
# Out:
# Keenan Akbar

# %%
emailuser2 = "Yoga Armando"

print(emailuser2)
# Out:
# Yoga Armando

# %%
#Hanya boleh menggunakan huruf angka dan underscore
email user 3 = "Dimas Esa"

print(email user 3)
# Out:
#   File "/tmp/ipython-input-948791985.py", line 2
#     email user 3 = "Dimas Esa"
#           ^
# SyntaxError: invalid syntax

# %%
emailUser3 = "Dimas Esa"

print(emailUser3)
# Out:
# Dimas Esa

# %%
#Tidak boleh didahului oleh angka
4_email_user = "Hanafi Naufal"

print(4_email_user)
# Out:
#   File "/tmp/ipython-input-4141522563.py", line 2
#     4_email_user = "Hanafi Naufal"
#      ^
# SyntaxError: invalid decimal literal

# %%
#Tidak boleh menggunakan kata kunci python
for = "Naufal Fajri"

print(for)
# Out:
#   File "/tmp/ipython-input-3000183539.py", line 2
#     for = "Naufal Fajri"
#         ^
# SyntaxError: invalid syntax

# %%
For = "Naufal Fajri"

print(For)
# Out:
# Naufal Fajri

# %%
print = "Alif Nadya"

print(print)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2601485791.py in <cell line: 0>()
#       1 print = "Alif Nadya"
#       2
# ----> 3 print(print)
#
# TypeError: 'str' object is not callable

# %%
Print = "Alif Nadya"

print(Print)
# Out:
# Alif Nadya

# %%
Nama = "Ahmad Fauzi"
Kelas = "X.12"
Hobi = "Membaca"

print(f)

# %% [markdown]
# #Assignment

# %%
#Single Assignment
beratbadansiswa1 = 90
print(beratbadansiswa1)
# Out:
# 90

# %%
#Multiple Assignment
nilai_kka_dias, nilai_kka_azka = 99, 98

print(nilai_kka_azka)
print(nilai_kka_dias)
# Out:
# 98
# 99

# %%
nilai_kka_dias, nilai_kka_azka = 99, 98, 70

print(nilai_kka_azka)
print(nilai_kka_dias)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-1966421120.py in <cell line: 0>()
# ----> 1 nilai_kka_dias, nilai_kka_azka = 99, 98, 70
#       2
#       3 print(nilai_kka_azka)
#       4 print(nilai_kka_dias)
#
# ValueError: too many values to unpack (expected 2)

# %%
#Chain Assignment
usia_anwar = usia_sahda = 20

print(usia_anwar)
print(usia_sahda)
# Out:
# 20
# 20

# %%
#Latihan Soal
nama = "Andi"

print(nama)
# Out:
# Andi

# %%
nama, umur, kelas = "Budi", 15, "9A"

print(nama, umur, kelas)
# Out:
# Budi 15 9A

# %%
berat_andi = berat_siti = berat_eko = 45,5

print(berat_andi,berat_siti,berat_eko)
# Out:
# (45, 5) (45, 5) (45, 5)

# %% [markdown]
# #Operasi dalam Phyton

# %%
#Tanpa variabel
print(8+2)
# Out:
# 10

# %%
#Operand disimpan ke variabel
kelereng_dias = 2
kelereng_azka = 8
print(kelereng_dias + kelereng_azka)
# Out:
# 10

# %%
#Hasil operasi disimpan ke variabel
total_kelereng = 8+2
print(total_kelereng)
# Out:
# 10

# %%
#Operand dan hasil operasi disimpan ke variabel
kelereng_azka = 8
kelereng_dias = 2
total_kelereng = kelereng_azka + kelereng_dias
print(total_kelereng)
# Out:
# 10

# %%
print(24*3)
# Out:
# 72

# %%
total_jumlah_botol = 24*3
print(total_jumlah_botol)
# Out:
# 72

# %%
banyak_botol_per_kardus = 24
jumlah_kardus = 3

print()

# %% [markdown]
# #Jenis Tipe Variabel

# %%
a = "handayani"
print(a)
type(a)
# Out:
# handayani
# str

# %%
b = -0.001
print(b)
type(b)
# Out:
# -0.001
# float

# %%
c = -50
print(c)
type(c)
# Out:
# -50
# int

# %%
d = True
print(d)
type(d)
# Out:
# True
# bool

# %%
d = true
print(d)
type(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3721722550.py in <cell line: 0>()
# ----> 1 d = true
#       2 print(d)
#       3 type(d)
#
# NameError: name 'true' is not defined

# %%
e = 1,89
print(e)
type(e)
# Out:
# (1, 89)
# tuple

# %%
x = False
print(x)
type(x)
# Out:
# False
# bool

# %%
type(-500)
# Out:
# int

# %%
k = float(88)
print(k)
type(k)
# Out:
# 88.0
# float

# %%
z = float(-100)
print(z)
type(z)
# Out:
# -100.0
# float

# %% [markdown]
# #Perubahan Tipe Variabel

# %%
f = 8.9
print(f)
type(f)
# Out:
# 8.9
# float

# %%
f = int(f)
print(f)
type(f)
# Out:
# 8
# int

# %%
g = -2.05
print(g)
type(g)
# Out:
# -2.05
# float

# %%
g = int(g)
print(g)
type(g)
# Out:
# -2
# int

# %%
g = bool(g)
print(g)
type(g)
# Out:
# True
# bool

# %%
h = True
print(h)
type(h)
# Out:
# True
# bool

# %%
h = int(h)
print(h)
type(h)
# Out:
# 1
# int

# %% [markdown]
# #Operator Perbandingan

# %%
print( 6 >= 6)
# Out:
# True

# %%
print(8 == 9)
# Out:
# False

# %%
print(8 != 9)
# Out:
# True

# %%
print(8 < 10)
# Out:
# True

# %%
print(8 > 10)
# Out:
# False

# %% [markdown]
# #Operator Logika

# %%
print(not(5 <= 5))
# Out:
# False

# %%
print(8 > 7 and 6 > 5)
# Out:
# True

# %%
print(7 <= 1 or 2 != 2)
# Out:
# False

# %%
print(not(0 == 1 and 1 != 1))
# Out:
# True

# %%
print(not(5 < 10 or 5 <= 10))
# Out:
# False

# %%
pendaftaran taruna
syarat:
a. tinggi minimal 165
b. berat badan minimal 50
c. dan tidak boleh umur lebih dari 25

tinggi_nino = 170
berat_nino = 55
umur_nino = 23
